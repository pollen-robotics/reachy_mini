# %% [markdown]
# # 📘 Notebook 0 — First Connection & Movement
#
# > 🎯 **Goal**: Connect to Reachy Mini and execute your first motion commands.
#
# ---
#
# ## 0. What You Will Learn
#
# By the end of this notebook, you will be able to:
#
# * Understand Reachy Mini's architecture (daemon + SDK)
# * Connect to your robot (real hardware or simulation)
# * Execute basic motion commands
# * Control the head and antennas
# * Practice safe robot operation
#
# **Duration:** 15-20 minutes
#
# > **Before you start:**
# > Make sure you've followed all setup steps in the requirements section of the notebooks' [`README.md`](README.md) before diving into this notebook!

# %% [markdown]
# ---
#
# ## 1. Architecture Overview
#
# Reachy Mini uses a **client-server architecture**:
#
# ```
# ┌─────────────────┐         ┌──────────────────┐
# │  Your Python    │         │   Reachy Daemon  │
# │  Script/Notebook│ ◄─────► │   (Server)       │
# │  (Client)       │         │                  │
# └─────────────────┘         └────────┬─────────┘
#                                      │
#                                      ▼
#                             ┌─────────────────┐
#                             │  Robot Hardware │
#                             │  or Simulation  │
#                             └─────────────────┘
# ```
#
# **Key Concepts:**
#
# * **Daemon**: A background service that directly controls the robot's motors, sensors, camera, and audio
# * **Python SDK**: The `reachy_mini` package you'll use to send commands
#
# **Why this architecture?**
# - Multiple clients can connect simultaneously (web app, scripts, notebooks)
# - The daemon handles low-level hardware safely
# - You can control the robot remotely over the network. For example, you can run your AI code on a powerful server while the Daemon runs on a Raspberry Pi connected to the robot.

# %% [markdown]
# ---
#
# ## 2. Verify Connection
#
# Before running code, let's verify the robot is up and running.
#
# You should use **Reachy Mini Control** to check that your robot is connected and ready. Reachy Mini Control is a desktop app that lets you manage your robot, run apps, play expressions, and control its sound system. Download it from the [official website](https://hf.co/reachy-mini/#/download) if you haven't already.
#
# Once connected in Reachy Mini Control, make sure the robot is **ON**.
#
# **Make sure the robot is ON before proceeding! Especially with the wireless version, the robot's code is OFF by default when the robot is powered on.**
#
# Refer to the [Connection & Reachy Mini Control section](https://huggingface.co/docs/reachy_mini/troubleshooting#-connection--reachy-mini-control) of the documentation for troubleshooting.

# %% [markdown]
# ---
#
# ## 3. First Connection
#
# Let's connect to the robot with Reachy's Python SDK!

# %%
# Import the ReachyMini class
from reachy_mini import ReachyMini

# Connect to the robot
# Note: We're using media_backend="no_media" to skip camera/audio for now
# We'll explore media in the next notebook!
with ReachyMini() as mini:
    print("Successfully connected to Reachy Mini!")
    print(f"Robot name: {mini.robot_name}")

# %% [markdown]
# **Important Notes:**
#
# * **`with` statement**: This is Python's context manager. It ensures the connection is properly closed when done.

# %% [markdown]
# ---
#
# ## 4. 🚨 Safety & Best Practices
#
# ### Emergency Stop
#
# If anything goes wrong:
# * **In Jupyter**: Click the "Stop" button (■) in the toolbar, or press `Ctrl+C` in terminal
# * **In Python script**: Press `Ctrl+C`
# * The `with` statement ensures the robot stops safely when the context exits
#
# ### Best Practices
#
# 1. **Always use the `with` statement**
#    ```python
#    with ReachyMini() as mini:
#        # Your code here
#    # Connection automatically closed here
#    ```
#
# 2. **Start with longer durations** (1-2 seconds) when experimenting
#    - Slower movements are safer
#    - You can speed up once you're comfortable
#
# 3. **Test small movements first**
#    - Start with small angles (5-10 degrees)
#    - Gradually increase range as you learn the limits
#
# 4. **Keep an eye on the robot**
#    - Watch for unexpected behavior
#    - Make sure the workspace is clear
#
# 5. **Try in simulation**
#    - You can also play with Reachy Mini in simulation!
#    - Just instanciate the daemon with the sim argument in a terminal: `reachy-mini-daemon --sim`.
#    This will open a Mujoco simulation window where you can see and control Reachy Mini without the physical hardware. This is a great way to experiment safely and test your code before running it on the real robot. More information about simulation can be found in the [simulation section](https://huggingface.co/docs/reachy_mini/platforms/simulation/get_started) of the documentation.

# %% [markdown]
# ---
#
# ## 5. First Movement
#
# Let's make Reachy Mini move! We'll start with a simple expressive pose, then come back to the **neutral position** — a safe, centered pose you'll use as a reference throughout all the notebooks.

# %%
from reachy_mini.utils import create_head_pose

with ReachyMini() as mini:
    # Let's start with an expressive pose: head tilted, antennas spread out
    print("Moving to a curious pose...")
    mini.goto_target(
        head=create_head_pose(roll=20, degrees=True),  # Tilt head to the right
        antennas=[0.3, -0.3],  # Spread antennas outward
        duration=2.0,
    )

    # Now return to neutral: head looking forward, antennas pointing straight up
    print("Returning to neutral position...")
    mini.goto_target(
        head=create_head_pose(),  # Neutral head pose (all zeros)
        antennas=[0.0, 0.0],  # Neutral antenna positions (radians)
        duration=2.0,
    )

    print("Done!")

# %% [markdown]
# **What Just Happened?**
#
# * **`goto_target()`**: Smoothly moves the robot from its current position to the target position
# * **`create_head_pose(roll=20, degrees=True)`**: Creates a head pose with a 20° tilt to the right. The `degrees=True` flag lets you use degrees instead of radians.
# * **`antennas=[0.3, -0.3]`**: Spreads both antennas outward (right antenna inward `+`, left antenna inward `-`)
# * **`create_head_pose()`**: Called with no arguments, this creates the **neutral pose** (x=0, y=0, z=0, roll=0, pitch=0, yaw=0) — head looking straight forward
# * **`antennas=[0.0, 0.0]`**: Both antennas pointing straight up — the neutral antenna position
# * **`duration=2.0`**: The movement takes 2 seconds. Longer = slower and smoother; shorter = faster
#
# > **Tip:** Returning to neutral position between movements is a good habit, it gives you a predictable starting point and keeps the robot safe.

# %% [markdown]
# ---
#
# ## 6. Moving the Head
#
# The head has 6 degrees of freedom :
# - translation :
#      - X axis
#      - Y axis
#      - Z axis
# - rotation :
#      - roll
#      - pitch
#      - yaw
#
# Let's explore each one !

# %% [markdown]
# ### 6.1. Translation
#
# The head can translate :
# - back and forth (on the X axis)
# - from the right to the left (on the Y axis)
# - from bottom to top (on the Z-axis)
#
# <p align="center">
#     <img src="https://github.com/pollen-robotics/reachy_mini/raw/main/docs/assets/reachy_mini_head_axis.png" alt="head axis" width ="40%"/>
# </p>

# %%
with ReachyMini() as mini:
    # Start from neutral
    mini.goto_target(head=create_head_pose(), antennas=[0.0, 0.0], duration=1.0)

    # X axis : translate back and forth
    print("Translate backwards...")
    mini.goto_target(
        head=create_head_pose(x=-0.02),  # Translate head 2 cm backwards
        duration=1.0,
    )

    print("Translate forwards...")
    mini.goto_target(
        head=create_head_pose(x=0.02),  # Translate head 2 cm forwards
        duration=1.0,
    )

    # Return to neutral
    mini.goto_target(head=create_head_pose(), duration=1.0)

    # Y axis : translate from right to left
    print("Translate to the right...")
    mini.goto_target(
        head=create_head_pose(y=-0.02),  # Translate head 2 cm to the right
        duration=1.0,
    )

    print("Translate to the left...")
    mini.goto_target(
        head=create_head_pose(y=0.02),  # Translate head 2 cm to the left
        duration=1.0,
    )

    # Return to neutral
    mini.goto_target(head=create_head_pose(), duration=1.0)

    # Zaxis : translate from bottom to top
    print("Translate downwards...")
    mini.goto_target(
        head=create_head_pose(z=-0.02),  # Translate head 2 cm downwards
        duration=1.0,
    )

    print("Translate upwards...")
    mini.goto_target(
        head=create_head_pose(z=0.02),  # Translate head 2 cm upwards
        duration=1.0,
    )

    # Return to neutral
    mini.goto_target(head=create_head_pose(), duration=1.0)

    print("Done!")

# %% [markdown]
# **What just happened?**
#
# * **`goto_target()`**: Smoothly moves the robot from its current position to the target position
# * **`create_head_pose()`**: Creates the head pose you want, according to the parameters you specify. Here, only the translation values are modified (x, y or z). You can of course modify all parameters simultaneously.

# %% [markdown]
# ### 6.2. Rotation
#
# The head can rotate along 3 axes :
#
# * **Roll**: Tilting (Rotation around the X-axis)
#   - Positive = tilt right
#   - Negative = tilt left
#
# * **Pitch**: Nodding up/down (Rotation around the Y-axis)
#   - Positive = looking down
#   - Negative = looking up
#
# * **Yaw**: Shaking left/right (Rotation around the Z-axis)
#   - Positive = looking left
#   - Negative = looking right
#
# <p align="center">
#     <img src="https://github.com/pollen-robotics/reachy_mini/raw/main/docs/assets/reachy_mini_head_rotation.png" alt="head rotation" width ="40%"/>
# </p>

# %%
with ReachyMini() as mini:
    # Start from neutral
    mini.goto_target(head=create_head_pose(), antennas=[0.0, 0.0], duration=1.0)

    # Roll: Tilt head (like a confused look, right and left)
    print("Tilting head right...")
    mini.goto_target(head=create_head_pose(roll=20, degrees=True), duration=1.0)

    # Return to neutral
    mini.goto_target(head=create_head_pose(), duration=1.0)

    print("Tilting head left...")
    mini.goto_target(head=create_head_pose(roll=-20, degrees=True), duration=1.0)

    # Return to neutral
    mini.goto_target(head=create_head_pose(), duration=1.0)

    # Pitch: Nod "yes" (down and up)
    print("Nodding head down...")
    mini.goto_target(head=create_head_pose(pitch=15, degrees=True), duration=1.0)

    print("Nodding head up...")
    mini.goto_target(head=create_head_pose(pitch=-15, degrees=True), duration=1.0)

    # Return to neutral
    mini.goto_target(head=create_head_pose(), duration=1.0)

    # Yaw: Shake "no" (left and right)
    print("Shaking head left...")
    mini.goto_target(head=create_head_pose(yaw=30, degrees=True), duration=1.0)

    print("Shaking head right...")
    mini.goto_target(head=create_head_pose(yaw=-30, degrees=True), duration=1.0)

    # Return to neutral
    mini.goto_target(head=create_head_pose(), duration=1.0)

    print("Done!")

# %% [markdown]
# **Important:** Always use `degrees=True` when working with degrees!
#
# Reachy Mini has physical and software limits to prevent self-collision and damage. The SDK will automatically clamp values to the closest valid position. For example the roll limits are +/- 40 degrees meaning that if you try to set a roll to 50 degrees, it will be clamped to 40 degrees.
# The complete ranges are documented in the [core concepts section](https://huggingface.co/docs/reachy_mini/SDK/core-concept#safety-limits-) of the documentation.

# %% [markdown]
# ---
#
# ## 7. Moving the Antennas
#
# The antennas are great for expressing emotions and attention!

# %%
import numpy as np

with ReachyMini() as mini:
    # Start neutral
    mini.goto_target(head=create_head_pose(), antennas=[0.0, 0.0], duration=1.0)

    # Both antennas outward (excited/alert)
    print("Excited!")
    for _ in range(5):
        mini.goto_target(
            head=create_head_pose(),
            antennas=[
                np.deg2rad(-10),
                np.deg2rad(10),
            ],  # Right outward (-), Left outward (+)
            duration=0.1,
        )
        mini.goto_target(
            head=create_head_pose(),
            antennas=[
                np.deg2rad(10),
                np.deg2rad(-10),
            ],  # Right outward (+), Left outward (-)
            duration=0.1,
        )

    # Both antennas outward (sad/tired)
    print("Sad...")
    mini.goto_target(
        head=create_head_pose(),
        antennas=[
            np.deg2rad(-140),
            np.deg2rad(140),
        ],  # Right outward (-), Left outward (+)
        duration=3.0,
    )

    # # Return to neutral
    mini.goto_target(head=create_head_pose(), antennas=[0.0, 0.0], duration=1.0)

    # # Alternating (thinking/confused)
    print("Confused?")
    mini.goto_target(
        head=create_head_pose(),
        antennas=[np.deg2rad(-60), np.deg2rad(-30)],
        duration=1.0,
    )  # Right out, left in - we don't put the same value to create the confusion effect

    # Return to neutral
    mini.goto_target(head=create_head_pose(), antennas=[0.0, 0.0], duration=1.0)

    print("Done!")

# %% [markdown]
# **Antenna Control Tips:**
#
# * Antennas are specified as `[right, left]` in **radians** and point in the same direction : a **positive** command will move the antenna to the **right**, and a **negative** command will move it to the **left**. Thus you have to reverse the commands between the two to be symmetrical:
#   - Right antenna:
#     - Negative values tilt outward
#     - Positive values tilt inward
#   - Left antenna:
#     - Positive values tilt outward
#     - Negative values tilt inward
# * You can convert degrees to radians: `np.deg2rad(45)` or `np.radians(45)`
# * Antennas are great for expressing personality! Don't hesitate to play with them to give Reachy Mini more character

# %% [markdown]
# ---
#
# ## 8. Combining Head and Antenna Movements
#
# Let's create a more complex expression by combining both!

# %%
with ReachyMini() as mini:
    # Curious expression: tilt head + asymmetric antennas
    print("Curious...")
    mini.goto_target(
        head=create_head_pose(roll=20, degrees=True),
        antennas=[np.deg2rad(-60), np.deg2rad(-30)],
        duration=2.0,
    )

    # Return to neutral
    mini.goto_target(head=create_head_pose(), antennas=[0.0, 0.0], duration=1.0)

    # Sad: head down + antennas drooping
    print("Sad...")
    mini.goto_target(
        head=create_head_pose(pitch=30, degrees=True),
        antennas=(np.deg2rad(-140), np.deg2rad(140)),
        duration=3.0,
    )

    # Return to neutral
    mini.goto_target(head=create_head_pose(), antennas=[0.0, 0.0], duration=1.0)

    print("Done!")

# %% [markdown]
# **Tips for Combining Movements:**
#
# **You can create expressive behaviors** by synchronizing head orientation with antenna positions. For example:
# - Sad expression: head looking down + antennas dropping outward
# - Curious expression: head tilted + asymmetric antennas
# - Excited expression: head up + antennas moving rapidly
# * **Timing is key**: Use longer durations (2-3 seconds) for emotional expressions to make them more believable and natural
# * **Experiment with asymmetry**: Different antenna positions create more personality and character

# %% [markdown]
# ---
#
# ## 9. Playing Pre-Recorded Emotions
#
# Manually crafting every pose is expressive, but Reachy Mini also ships with a **library of pre-recorded emotions** — full motion sequences combining head and antenna movements to express feelings like joy, surprise, boredom, and more.
#
# These are stored in the [pollen-robotics/reachy-mini-emotions-library](https://huggingface.co/datasets/pollen-robotics/reachy-mini-emotions-library) HuggingFace dataset and can be streamed and played directly from the SDK. You can browse and preview all of them in the [Reachy Mini Emotion App](https://huggingface.co/spaces/RemiFabre/emotions).
#
# Let's load the dataset and play a few!

# %%
from reachy_mini.motion.recorded_move import RecordedMoves

EMOTIONS_DATASET = "pollen-robotics/reachy-mini-emotions-library"

emotions = RecordedMoves(EMOTIONS_DATASET)

print(f"{len(emotions.list_moves())} emotions available:")
print(emotions.list_moves())

# %% [markdown]
# 81 emotions are available in the app, and you can also create your own custom emotions by controlling the head and antennas with the SDK. This is a great way to practice and get creative with Reachy Mini's expressiveness!
#
# Let's play a random emotion from the app to see how it looks on the robot! You can run this cell multiple times to see different emotions. Each time you run it, it will randomly select one of the 81 emotions and execute the corresponding head and antenna movements on your Reachy Mini. This is a fun way to explore the range of expressions your robot can make!
#
# You can try to replicate them with your robot and use this as inspiration for your own expressions!

# %%
# Pick a random emotion from the dataset and play it
import random

with ReachyMini() as mini:
    emotion_name = random.choice(emotions.list_moves())
    print(f"Playing '{emotion_name}'...")
    await mini.async_play_move(emotions.get(emotion_name), initial_goto_duration=1.0)
    print("Done!")

# %% [markdown]
# ## 10. Exercises (Try It Yourself!)
#
# ### Exercise 1: Create a Greeting Gesture
#
# Create a sequence that:
# 1. Looks up slightly
# 2. Tilts head to one side
# 3. Wiggles antennas
# 4. Returns to neutral
#
# **Hint:** Use multiple `goto_target()` calls in sequence.
#
# <details>
# <summary><b>💡 Click to reveal answer</b></summary>
#
# ```python
# from reachy_mini import ReachyMini
# from reachy_mini.utils import create_head_pose
#
# with ReachyMini(media_backend="no_media") as mini:
#     # 1. Look up slightly
#     mini.goto_target(
#         head=create_head_pose(pitch=-10, degrees=True),
#         antennas=[0.0, 0.0],
#         duration=1.0
#     )
#
#     # 2. Tilt head to one side
#     mini.goto_target(
#         head=create_head_pose(roll=15, pitch=-10, degrees=True),
#         duration=1.0
#     )
#
#     # 3. Wiggle antennas - remember the excited sequence in the antenna control part?
#     for _ in range(5):
#         mini.goto_target(
#         antennas=[-0.3, 0.3],
#         duration=0.1
#         )
#         mini.goto_target(
#             antennas=[0.3, -0.3],
#             duration=0.1
#         )
#
#     # 4. Return to neutral
#     mini.goto_target(
#         head=create_head_pose(),
#         antennas=[0.0, 0.0],
#         duration=1.5
#     )
#
#     print("Greeting complete!")
# ```
#
# </details>

# %%
# Your code here
from reachy_mini import ReachyMini
from reachy_mini.utils import create_head_pose

with ReachyMini() as mini:
    # TODO: Create your greeting gesture
    pass

# %% [markdown]
# ### Exercise 2: Experiment with Duration
#
# Move the head from neutral to `yaw=30°` three times with different durations:
# - 0.5 seconds (fast)
# - 2.0 seconds (normal)
# - 5.0 seconds (slow)
#
# Go back to neutral position after each movement. Observe how the movement speed changes.
#
# <details>
# <summary><b>💡 Click to reveal answer</b></summary>
#
# ```python
# from reachy_mini import ReachyMini
# from reachy_mini.utils import create_head_pose
#
# with ReachyMini(media_backend="no_media") as mini:
#     # Start from neutral
#     mini.goto_target(head=create_head_pose(), duration=1.0)
#
#     # Fast movement (0.5s)
#     print("Fast movement (0.5s)...")
#     mini.goto_target(
#         head=create_head_pose(yaw=30, degrees=True),
#         duration=0.5
#     )
#     mini.goto_target(head=create_head_pose(), duration=0.5)
#
#     # Normal movement (2.0s)
#     print("Normal movement (2.0s)...")
#     mini.goto_target(
#         head=create_head_pose(yaw=30, degrees=True),
#         duration=2.0
#     )
#     mini.goto_target(head=create_head_pose(), duration=2.0)
#
#     # Slow movement (5.0s)
#     print("Slow movement (5.0s)...")
#     mini.goto_target(
#         head=create_head_pose(yaw=30, degrees=True),
#         duration=5.0
#     )
#     mini.goto_target(head=create_head_pose(), duration=5.0)
#
#     print("Duration experiment complete!")
# ```
#
# </details>

# %%
# Your code here
from reachy_mini import ReachyMini
from reachy_mini.utils import create_head_pose

with ReachyMini() as mini:
    # TODO: Test different durations
    pass

# %% [markdown]
# ### Exercise 3: Create an "Attention" Animation
#
# Make Reachy look like it's paying attention:
# 1. Start neutral
# 2. Look slightly to the left
# 3. Look slightly to the right
# 4. Look forward and tilt head slightly (listening pose)
# 5. Return to neutral
#
# Make it smooth and natural!
#
# <details>
# <summary><b>💡 Click to reveal answer</b></summary>
#
# ```python
# from reachy_mini import ReachyMini
# from reachy_mini.utils import create_head_pose
#
# with ReachyMini(media_backend="no_media") as mini:
#     # 1. Start neutral
#     print("Starting attention animation...")
#     mini.goto_target(
#         head=create_head_pose(),
#         antennas=[0.0, 0.0],
#         duration=1.0
#     )
#
#     # 2. Look slightly to the left
#     mini.goto_target(
#         head=create_head_pose(yaw=25, degrees=True),
#         duration=1.5
#     )
#
#     # 3. Look slightly to the right
#     mini.goto_target(
#         head=create_head_pose(yaw=-25, degrees=True),
#         duration=2.0
#     )
#
#     # 4. Look forward and tilt head slightly (listening pose)
#     mini.goto_target(
#         head=create_head_pose(roll=20, degrees=True),
#         antennas=[-1.0, -0.5],
#         duration=2.0
#     )
#
#     # 5. Return to neutral
#     mini.goto_target(
#         head=create_head_pose(),
#         antennas=[0.0, 0.0],
#         duration=2.0
#     )
#
#     print("Attention animation complete!")
# ```
#
# **Tip:** The key to natural-looking movements is using appropriate durations and smooth transitions between poses. Experiment with different timings to find what looks best!
#
# </details>

# %%
# Your code here
from reachy_mini import ReachyMini
from reachy_mini.utils import create_head_pose

with ReachyMini() as mini:
    # TODO: Create attention animation
    pass

# %% [markdown]
# ---
#
# ## 10. What's Next?
#
# Congratulations! You've learned how to:
# * ✅ Connect to Reachy Mini
# * ✅ Move the head with pitch, yaw, and roll
# * ✅ Control the antennas
# * ✅ Create combined movements
# * ✅ Follow safety best practices
#
# In the next notebook, you'll learn:
# * 📸 How to get images from the camera
# * 🎤 How to record audio from the microphone
# * 🔊 How to play sounds through the speaker
#
# ➡️ **Next: Notebook 1 — Basic Media (Camera & Audio)** 📷🎵
